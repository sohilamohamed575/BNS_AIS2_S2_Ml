# %%
list_1 = [1, 2, 3, 4, "depi", "learning", True, [1, 2, 3, "true", ["ML", "DL", "GenAI"]]]

# %%
(list_1[7][4][1]) = "Deep Learning"

# %%
print(list_1)
# Out:
# [1, 2, 3, 4, 'depi', 'learning', True, [1, 2, 3, 'true', ['ML', 'Deep Learning', 'GenAI']]]

# %%
Input_list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]

item_to_remove = input("Enter the item you want to remove: ")

if item_to_remove in Input_list:
    Input_list.remove(item_to_remove)
    print("Modified list:", Input_list)
else:
    print("Item not found in the list.")
# Out:
# Modified list: ['amit', 'learning', 'python', 'data science', 'deep learning']

# %%
def is_prime(num: int) -> bool:
    """
    check for the number is prime or not

    Args:
        num(int): number for check
    Returns:
        bool: true if that prime or false if that not prime
    """
    if num < 2:
        return False
    for i in range(2, num):
        if num % i == 0:
            return False
    return True

# %%
class StudentInfo:
    name = "George"
    age = 39

    def std_info(self):
        print(self)

s1 = StudentInfo()
print(s1)
print(s1.std_info())
# Out:
# <__main__.StudentInfo object at 0x00000162DB7877A0>
# <__main__.StudentInfo object at 0x00000162DB7877A0>
# None

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def move(self):
        pass

class Bird(Animal):
    def move(self):
        print("Bird is flying")

a = Bird()
a.move()
# Out:
# Bird is flying

# %%
class parent:
    def __init__(self) -> None:
        self.__value = 10

class child(parent):
    def __init__(self) -> None:
        super().__init__()
        self.__value = 20

# %%
c = child()
print(c.__dict__)
# Out:
# {'_parent__value': 10, '_child__value': 20}

# %%
class Shape:
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def calculate_area(self):
        return self.width * self.height

class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def calculate_area(self):
        return 0.5 * self.base * self.height

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def calculate_area(self):
        return self.side ** 2

x = Circle(5)
y = Rectangle(4, 6)
z = Triangle(3, 4)
w = Square(5)

# %%
class MOdel:
    def pridect(self, x):
        raise NotImplementedError

class LinearRegression(MOdel):
    def pridect(self, x):
        return " Linear Regression prediction"

class DecisionTree(MOdel):
    def pridect(self, x):
        return " DecisionTree prediction"

models = [LinearRegression(), DecisionTree()]
for model in models:
    print(model.pridect(None))
# Out:
#  Linear Regression prediction
#  DecisionTree prediction

# %%
import numpy as np

def create_zero_matrix(value=0):
    return np.full((3, 3), value)

matrix = create_zero_matrix()
print(matrix)
# Out:
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]

# %%
import pandas as pd
pd.Series([1, 2, 3,4 ])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
import pandas as pd

data = [[1, 444, "abc"],
        [2, 555, "def"],
        [3, 666, "ghi"],
        [4, 444, "xyz"]]

df = pd.DataFrame(data, columns=['col1', 'col2', 'col3'])

print(df)
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
import pandas as pd

data = [[1, 444, "abc"],
        [2, 555, "def"],
        [3, 666, "ghi"],
        [4, 444, "xyz"]]

df = pd.DataFrame(data)

df.columns = ['ip', 'salary', 'depart']
df.index = ['s', 'm', 't', 'u']

print(df)
# Out:
#    ip  salary depart
# s   1     444    abc
# m   2     555    def
# t   3     666    ghi
# u   4     444    xyz

# %%
df.dtypes
# Out:
# ip        int64
# salary    int64
# depart      str
# dtype: object

# %%
df.ip.dtype
# Out:
# dtype('int64')

# %%
df.salary.dtype
# Out:
# dtype('int64')

# %%
df.depart.dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df['salary'] = df['salary'].astype(int)

# %%
data = [[1, 444, "abc"],
        [2, 555, "def"],
        [3, 666, "ghi"],
        [4, 444, "xyz"]]
df.depart.unique()
display(df.head(3))
display(df.tail(2))
print(df.depart.nunique())
# Out:
#    ip  salary depart
# s   1     444    abc
# m   2     555    def
# t   3     666    ghi
#    ip  salary depart
# t   3     666    ghi
# u   4     444    xyz
# 4

# %%
df["salary"].max()
# Out:
# np.int64(666)

# %%
df["salary"].min()
# Out:
# np.int64(444)

# %%
def get_range_of_salary(df):
	return df["salary"].max() - df["salary"].min()
print(get_range_of_salary(df))
# Out:
# 222

# %%
df.salary.value_counts()
# Out:
# salary
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, s to u
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ip      4 non-null      int64
#  1   salary  4 non-null      int64
#  2   depart  4 non-null      str
# dtypes: int64(2), str(1)
# memory usage: 316.0 bytes

# %%
df["salary"].values
# Out:
# array([444, 555, 666, 444])

# %%
df.values
# Out:
# array([[1, 444, 'abc'],
#        [2, 555, 'def'],
#        [3, 666, 'ghi'],
#        [4, 444, 'xyz']], dtype=object)

# %%
df.replace(555, "sohila")
# Out:
#    ip  salary depart
# s   1     444    abc
# m   2  sohila    def
# t   3     666    ghi
# u   4     444    xyz

# %%
import pandas as pd
df = pd.read_csv('Titanic.csv')
df.drop(['PassengerId','Name','Ticket' ], axis = 1 ,inplace = True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
import pandas as pd
df = pd.read_csv('Titanic.csv')
df.drop(['PassengerId', 'Name', 'Ticket'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
def drop_columns(df, columns):
    return df.drop(columns=columns)

# %%
DROP_CLO = ['PassengerId', 'Name', 'Ticket']

def drop_columns(df, columns):
    return df.drop(columns=columns, errors='ignore')

drop_columns(df, DROP_CLO)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
dtypes = df.dtypes
df.nunique()
# Out:
# Survived      2
# Pclass        3
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Fare        248
# Cabin       147
# Embarked      3
# dtype: int64

# %%
dtypes = df.dtypes
n_unique = df.nunique()
pd.DataFrame({"Dtypes ": dtypes, "N_unique ": n_unique}).T
# Out:
#           Survived Pclass  Sex      Age  SibSp  Parch     Fare Cabin Embarked
# Dtypes       int64  int64  str  float64  int64  int64  float64   str      str
# N_unique         2      3    2       88      7      7      248   147        3

# %%
df.isnull()
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch   Fare  Cabin  Embarked
# 0       False   False  False  False  False  False  False   True     False
# 1       False   False  False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False   True     False
# 3       False   False  False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False   True     False
# ..        ...     ...    ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False   True     False
# 887     False   False  False  False  False  False  False  False     False
# 888     False   False  False   True  False  False  False   True     False
# 889     False   False  False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False   True     False
#
# [891 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
null = df.isnull().sum()
ratio = null / 891
ratio
# Out:
# Survived    0.000000
# Pclass      0.000000
# Sex         0.000000
# Age         0.198653
# SibSp       0.000000
# Parch       0.000000
# Fare        0.000000
# Cabin       0.771044
# Embarked    0.002245
# dtype: float64
